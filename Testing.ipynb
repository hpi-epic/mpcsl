# %%
import numpy as np
import pandas as pd

# %%
mean = [0, 5, 10]
cov = [[1, 0, 0], [0, 10, 0], [0, 0, 20]]

# %%
pd.DataFrame(np.random.multivariate_normal(mean, cov, size=1000), columns=['X1', 'X2', 'X3'])
# Out:
#            X1         X2         X3
# 0   -1.285806   1.158356   7.325413
# 1   -2.380958   3.951719  15.574394
# 2    2.095175   2.766281  15.279342
# 3    0.290752   5.271045   5.363200
# 4    0.353046   3.601320   5.298152
# 5   -2.085458  13.209941   6.535201
# 6    0.895748   9.380638   6.126675
# 7   -0.471516   4.863709  15.215093
# 8   -1.009401   2.620153  13.225402
# 9    0.581881   1.139586   3.317971
# 10  -0.229839   7.179521   1.922439
# 11  -1.961013   2.023825   3.511479
# 12  -0.273201   4.300173  16.343416
# 13  -1.423808  -2.412398  13.902521
# 14  -0.151398   3.423977   3.242726
# 15   0.944190   4.197545  11.658836
# 16   0.640636   1.828421   5.468690
# 17  -1.499954   6.259735   4.406813
# 18   0.954478   8.424338   9.044640
# 19  -0.487179   3.189775   4.332243
# 20   0.794560   4.082900  12.372269
# 21  -2.730244   7.236516   9.478834
# 22  -0.008406   7.249310   9.817986
# 23  -2.445760   6.374738  10.175094
# 24  -0.415865   1.232264   6.385963
# ...
